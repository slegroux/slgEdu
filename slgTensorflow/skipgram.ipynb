# %%
import os
from __future__ import print_function
import collections
import math
import numpy as np
from matplotlib import pyplot as plt
import os
import random
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from IPython import embed
# %matplotlib inline

# %% [markdown]
# http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes, data_dir):
    file_path = data_dir + '/' + filename
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(file_path):
        filename, _ = urlretrieve(url + filename, file_path)
    statinfo = os.stat(file_path)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return file_path


file_path = maybe_download('text8.zip', 31344016, "db")
file_path
# Out:
# Found and verified text8.zip
# 'db/text8.zip'

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(file_path)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'first', 'against']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['term', 'anarchism', 'originated', 'a', 'originated', 'term', 'of', 'as', 'of', 'a', 'abuse', 'as', 'first', 'abuse', 'a', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['a', 'originated', 'term', 'as', 'a', 'of', 'term', 'abuse', 'first', 'of', 'used', 'abuse', 'against', 'first', 'used', 'early']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['of', 'term', 'originated', 'as', 'a', 'abuse', 'as', 'of', 'a', 'abuse', 'term', 'first', 'first', 'of', 'term', 'used']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.633060
# Nearest to many: turtles, dalits, industry, ili, capybaras, tate, retaliated, vivid,
# Nearest to they: disenfranchised, clades, fills, notional, willy, kristian, verses, timeline,
# Nearest to known: intolerable, repressed, hao, fisc, drinkers, rdx, entanglement, abomination,
# Nearest to is: tournament, orientation, efficacy, stoic, scanline, dimitri, kinase, hanging,
# Nearest to states: enso, statistic, pandemonium, nec, andriessen, prepare, yorktown, kruger,
# Nearest to system: theologians, softball, translated, nikki, intuitive, cypress, brownian, socialize,
# Nearest to on: flickering, adapa, reputable, poem, innovated, quicker, folklore, abstaining,
# Nearest to seven: organising, hikers, puzzles, bmw, dhrystone, bumped, plantagenet, suffragan,
# Nearest to such: teg, okinawa, causative, neurologic, autobahn, tasting, concluding, push,
# Nearest to one: indie, biographical, deleuze, cassette, fondness, encourages, cooley, displace,
# Nearest to it: overshadowed, bilinear, glowing, graviton, hogshead, contend, drags, oberon,
# Nearest to during: mapsto, mithra, mcintyre, nationalisation, renfrew, processor, currents, atonality,
# Nearest to not: benchmarks, meteorologists, herring, neurotransmitters, interestingly, anton, outfield, abeda,
# Nearest to been: doctors, saint, battleships, mujahidin, drummer, shells, woodwind, angelic,
# Nearest to up: donald, macroscopic, writeup, chairmen, trout, rated, tic, hallmarks,
# Nearest to i: busey, viper, floating, finishing, dorians, toughness, rather, ramesses,
# Average loss at step 2000: 4.356591
# Average loss at step 4000: 3.859878
# Average loss at step 6000: 3.783057
# Average loss at step 8000: 3.683589
# Average loss at step 10000: 3.614163
# Nearest to many: some, those, several, dalits, languages, ili, viva, turtles,
# Nearest to they: he, it, not, disenfranchised, there, she, oubangui, who,
# Nearest to known: repressed, agriculturally, rdx, altruist, nucleosome, intolerable, operates, thinly,
# Nearest to is: was, are, has, sank, hermas, tensile, twenties, deutschlands,
# Nearest to states: pandemonium, yorktown, montrealers, meteorites, viking, laminar, statistic, malaysian,
# Nearest to system: translated, socialize, theologians, dardanelles, marija, splinter, resisted, mesoamerican,
# Nearest to on: in, fan, chained, at, separatists, about, clams, with,
# Nearest to seven: six, nine, eight, four, three, five, zero, two,
# Nearest to such: some, oftentimes, smoothed, cavelier, quotes, redstone, causative, faustina,
# Nearest to one: two, three, four, eight, seven, five, six, zero,
# Nearest to it: he, this, there, they, we, which, not, that,
# Nearest to during: ascetical, mapsto, franchising, deflecting, in, at, redactor, kestrel,
# Nearest to not: they, it, also, awaken, generally, to, often, manhunter,
# Nearest to been: samarium, doctors, also, amato, by, goetz, fairey, was,
# Nearest to up: macroscopic, campylobacter, writeup, rated, deflation, chairmen, wire, donald,
# Nearest to i: you, finishing, squat, viper, rather, firestorm, frightful, tyson,
# Average loss at step 12000: 3.605336
# Average loss at step 14000: 3.569325
# Average loss at step 16000: 3.407987
# Average loss at step 18000: 3.457005
# Average loss at step 20000: 3.540816
# Nearest to many: some, several, these, those, other, all, such, much,
# Nearest to they: he, there, it, we, she, who, you, not,
# Nearest to known: agriculturally, repressed, operates, used, such, thinly, rdx, intolerable,
# Nearest to is: was, has, are, be, were, hermas, revolver, burger,
# Nearest to states: yorktown, montrealers, pandemonium, laminar, peculiarities, chrysotile, viking, scaffold,
# Nearest to system: socialize, translated, armenians, zoom, marija, dardanelles, eigenvalues, splinter,
# Nearest to on: in, at, clams, fan, tidal, luz, killing, mesoamerican,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to such: oftentimes, well, many, quotes, these, known, smoothed, hectares,
# Nearest to one: two, four, three, six, eight, seven, nine, five,
# Nearest to it: he, this, there, they, which, she, we, not,
# Nearest to during: at, ascetical, in, franchising, is, by, upon, redactor,
# Nearest to not: it, tuatha, they, also, often, cordial, still, awaken,
# Nearest to been: be, become, was, already, partitioning, amato, were, had,
# Nearest to up: macroscopic, rated, campylobacter, sensory, homosexual, their, deflation, wire,
# Nearest to i: you, ii, tyson, vaikundar, we, finishing, firestorm, itis,
# Average loss at step 22000: 3.502936
# Average loss at step 24000: 3.486132
# Average loss at step 26000: 3.478776
# Average loss at step 28000: 3.477846
# Average loss at step 30000: 3.497314
# Nearest to many: some, several, these, those, all, various, such, their,
# Nearest to they: there, he, we, it, you, who, not, she,
# Nearest to known: used, such, regarded, possible, thinly, agriculturally, intolerable, operates,
# Nearest to is: was, has, are, if, were, ida, nautilus, became,
# Nearest to states: yorktown, chrysotile, soften, peculiarities, viking, enrollment, countries, pandemonium,
# Nearest to system: systems, geek, translated, marija, dardanelles, socialize, armenians, zoom,
# Nearest to on: in, fan, upon, about, cotangent, clams, within, at,
# Nearest to seven: eight, nine, five, six, four, three, zero, two,
# Nearest to such: well, these, known, many, some, claudine, reproducing, redstone,
# Nearest to one: two, seven, four, six, eight, nine, five, three,
# Nearest to it: he, there, this, they, she, which, unrecorded, still,
# Nearest to during: in, at, redactor, ascetical, by, deflecting, upon, after,
# Nearest to not: they, still, tuatha, too, often, generally, fairer, now,
# Nearest to been: become, be, was, already, partitioning, invalidated, powders, rebus,
# Nearest to up: macroscopic, him, rated, sensory, them, campylobacter, objects, homosexual,
# Nearest to i: ii, you, we, tyson, they, t, vaikundar, cyclopaedia,
# Average loss at step 32000: 3.498915
# Average loss at step 34000: 3.487243
# Average loss at step 36000: 3.456194
# Average loss at step 38000: 3.299070
# Average loss at step 40000: 3.425650
# Nearest to many: some, several, these, various, those, all, numerous, both,
# Nearest to they: there, we, he, you, it, i, she, not,
# Nearest to known: used, such, possible, regarded, agriculturally, magie, acceptable, operates,
# Nearest to is: was, are, has, be, sank, as, salamander, in,
# Nearest to states: chrysotile, kingdom, countries, nations, yorktown, scrupulous, peculiarities, onlookers,
# Nearest to system: systems, translated, dardanelles, weaned, geek, armenians, marija, eigenvalues,
# Nearest to on: upon, fan, at, in, about, around, during, ditto,
# Nearest to seven: eight, nine, six, five, four, three, zero, one,
# Nearest to such: well, these, known, granules, redstone, claudine, many, described,
# Nearest to one: seven, eight, four, six, two, five, nine, three,
# Nearest to it: he, there, she, this, they, which, not, clearly,
# Nearest to during: at, after, within, ascetical, deflecting, when, on, until,
# Nearest to not: they, it, still, tuatha, often, generally, cordial, also,
# Nearest to been: become, be, already, was, previously, partitioning, were, rebus,
# Nearest to up: them, him, sensory, macroscopic, down, out, objects, trip,
# Nearest to i: you, ii, we, tyson, they, t, he, suite,
# Average loss at step 42000: 3.434600
# Average loss at step 44000: 3.450350
# Average loss at step 46000: 3.449039
# Average loss at step 48000: 3.358076
# Average loss at step 50000: 3.383812
# Nearest to many: some, several, these, various, both, those, all, most,
# Nearest to they: there, we, he, you, she, it, who, not,
# Nearest to known: used, such, regarded, possible, seen, agriculturally, part, magie,
# Nearest to is: was, has, are, contains, does, be, exists, freiburg,
# Nearest to states: kingdom, chrysotile, nations, malaysian, countries, yorktown, scrupulous, onlookers,
# Nearest to system: systems, investiture, intuitive, dardanelles, geek, socialize, jersey, leith,
# Nearest to on: upon, at, around, through, fan, clams, in, within,
# Nearest to seven: eight, six, four, three, nine, five, zero, two,
# Nearest to such: well, known, these, many, follows, described, granules, claudine,
# Nearest to one: two, six, seven, eight, four, nine, three, five,
# Nearest to it: he, there, she, this, they, then, ihra, still,
# Nearest to during: after, at, in, within, but, until, by, under,
# Nearest to not: too, they, generally, tuatha, never, able, cordial, now,
# Nearest to been: become, be, already, previously, was, rebus, were, lynda,
# Nearest to up: them, down, out, him, off, sensory, trip, macroscopic,
# Nearest to i: ii, you, we, ramesses, tyson, suite, they, octane,
# Average loss at step 52000: 3.434644
# Average loss at step 54000: 3.432840
# Average loss at step 56000: 3.438770
# Average loss at step 58000: 3.390879
# Average loss at step 60000: 3.390900
# Nearest to many: some, several, various, these, those, all, most, both,
# Nearest to they: we, there, you, he, she, it, austerlitz, these,
# Nearest to known: used, possible, regarded, such, seen, agriculturally, well, called,
# Nearest to is: was, are, has, contains, be, if, seems, suggests,
# Nearest to states: kingdom, nations, countries, chrysotile, malaysian, onlookers, scully, soliah,
# Nearest to system: systems, investiture, dardanelles, program, condition, baldrick, marija, applications,
# Nearest to on: upon, within, in, through, clams, fan, around, poem,
# Nearest to seven: eight, nine, six, four, five, three, one, two,
# Nearest to such: well, these, known, many, follows, described, manzarek, fleetwood,
# Nearest to one: seven, two, eight, four, five, six, nine, three,
# Nearest to it: he, there, this, she, which, they, still, we,
# Nearest to during: after, until, in, while, when, within, before, although,
# Nearest to not: still, to, they, now, too, usually, never, tuatha,
# Nearest to been: become, be, previously, was, already, partitioning, rebus, poured,
# Nearest to up: out, them, down, him, off, sensory, trip, sourceforge,
# Nearest to i: you, we, ii, tyson, ramesses, they, octane, suite,
# Average loss at step 62000: 3.239963
# Average loss at step 64000: 3.260133
# Average loss at step 66000: 3.403461
# Average loss at step 68000: 3.388574
# Average loss at step 70000: 3.360465
# Nearest to many: some, several, various, these, all, numerous, few, most,
# Nearest to they: we, he, there, you, it, she, abt, these,
# Nearest to known: used, regarded, such, seen, possible, defined, agriculturally, referred,
# Nearest to is: was, are, has, be, does, seems, although, contains,
# Nearest to states: kingdom, nations, countries, chrysotile, soliah, scrupulous, onlookers, scully,
# Nearest to system: systems, program, leith, zoom, applications, condition, dardanelles, piecewise,
# Nearest to on: upon, through, in, within, at, around, clams, ditto,
# Nearest to seven: six, four, eight, nine, five, three, two, zero,
# Nearest to such: these, well, known, many, follows, few, granules, described,
# Nearest to one: two, seven, six, four, five, eight, nine, three,
# Nearest to it: he, there, she, this, they, still, which, we,
# Nearest to during: after, until, at, in, before, through, within, despite,
# Nearest to not: never, now, still, generally, usually, tuatha, capacities, departures,
# Nearest to been: become, be, previously, already, was, poured, grown, partitioning,
# Nearest to up: them, out, down, off, him, sensory, trip, campylobacter,
# Nearest to i: we, you, ii, tyson, g, ramesses, monophysitism, they,
# Average loss at step 72000: 3.370557
# Average loss at step 74000: 3.345913
# Average loss at step 76000: 3.309529
# Average loss at step 78000: 3.354104
# Average loss at step 80000: 3.378104
# Nearest to many: several, some, various, these, numerous, most, all, few,
# Nearest to they: we, he, there, you, she, it, abt, these,
# Nearest to known: used, regarded, seen, such, defined, possible, referred, called,
# Nearest to is: was, has, are, became, although, be, does, grows,
# Nearest to states: kingdom, nations, countries, chrysotile, soliah, scrupulous, workers, companies,
# Nearest to system: systems, program, socialize, marija, lobo, geek, condition, leith,
# Nearest to on: upon, through, in, ditto, within, at, under, fan,
# Nearest to seven: six, eight, five, four, nine, three, two, one,
# Nearest to such: well, these, follows, known, regarded, granules, described, manzarek,
# Nearest to one: seven, two, six, four, three, eight, five, nine,
# Nearest to it: he, there, she, this, they, itself, unrecorded, never,
# Nearest to during: after, in, before, when, until, within, despite, throughout,
# Nearest to not: still, never, usually, generally, it, actually, often, now,
# Nearest to been: become, be, already, previously, was, grown, poured, rebus,
# Nearest to up: out, down, them, off, him, sensory, trip, circumstantial,
# Nearest to i: we, you, ii, t, g, monophysitism, ramesses, baked,
# Average loss at step 82000: 3.406677
# Average loss at step 84000: 3.415979
# Average loss at step 86000: 3.385648
# Average loss at step 88000: 3.352437
# Average loss at step 90000: 3.368085
# Nearest to many: several, some, various, these, most, numerous, all, few,
# Nearest to they: we, he, there, she, you, it, who, maintainers,
# Nearest to known: used, regarded, such, seen, defined, possible, called, referred,
# Nearest to is: was, are, has, contains, be, although, remains, makes,
# Nearest to states: kingdom, nations, countries, chrysotile, scully, malaysian, companies, leveling,
# Nearest to system: systems, program, marija, concept, process, socialize, geek, plane,
# Nearest to on: upon, in, at, against, within, fincher, through, fan,
# Nearest to seven: eight, five, six, four, nine, three, zero, one,
# Nearest to such: well, known, these, follows, certain, regarded, described, seen,
# Nearest to one: seven, eight, two, four, six, five, three, nine,
# Nearest to it: he, she, there, they, this, itself, we, never,
# Nearest to during: after, before, in, within, until, through, throughout, at,
# Nearest to not: nor, still, never, able, actually, legally, sontag, now,
# Nearest to been: become, already, be, previously, was, rebus, grown, being,
# Nearest to up: out, down, off, them, him, back, sensory, ores,
# Nearest to i: we, ii, you, g, t, ssri, ramesses, tyson,
# Average loss at step 92000: 3.393390
# Average loss at step 94000: 3.250573
# Average loss at step 96000: 3.356132
# Average loss at step 98000: 3.240415
# Average loss at step 100000: 3.352409
# Nearest to many: several, some, various, numerous, these, few, those, all,
# Nearest to they: we, he, there, you, she, it, i, not,
# Nearest to known: regarded, used, such, seen, possible, defined, available, referred,
# Nearest to is: was, has, became, are, although, be, contains, refers,
# Nearest to states: kingdom, nations, countries, chrysotile, malaysian, rehab, soliah, scully,
# Nearest to system: systems, program, sailplane, project, storage, process, lobo, entertained,
# Nearest to on: upon, within, in, through, at, around, under, fan,
# Nearest to seven: eight, six, four, nine, five, three, two, zero,
# Nearest to such: well, known, follows, regarded, many, separate, these, certain,
# Nearest to one: seven, two, four, six, nine, eight, five, three,
# Nearest to it: he, she, this, they, there, unrecorded, itself, nothing,
# Nearest to during: after, in, within, until, throughout, when, before, through,
# Nearest to not: never, still, legally, actually, they, nor, manhunter, usually,
# Nearest to been: become, already, be, was, previously, grown, lynda, recently,
# Nearest to up: out, down, off, them, him, back, sensory, obstructing,
# Nearest to i: we, you, ii, they, ssri, he, cyclopaedia, rang,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f70c03698d67> in <module>()
#       2
#       3 tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
# ----> 4 two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
#
# NameError: name 'final_embeddings' is not defined

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
#     plt.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        plt.scatter(x, y)
        plt.annotate(
            label,
            xy=(x, y),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom'
        )

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# <matplotlib.figure.Figure at 0x11b591110>
